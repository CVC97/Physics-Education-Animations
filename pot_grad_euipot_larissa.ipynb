# %%
from manim import *
from classes.electrodynamics_classes import *
import jupyter_capture_output

video_scene = " -v WARNING --progress_bar None --disable_caching pge_larissa_Scene"
image_scene = f" -v WARNING --progress_bar None --disable_caching -r {2*427},{2*240}  -s pge_larissa_Scene"
# Out:
# Manim Community v0.18.0.post0
# Jupyter Capture Output v0.0.11

# %%
# %%capture_video --path "animations/potential_gradient_equipot/pge_L.mp4"
# %%manim -qm --fps 60 $video_scene
#
#
# class pge_larissa_Scene(ThreeDScene):
#     def construct(self):
#
#     # self.camera.background_color = WHITE
#     # self.set_camera_orientation(phi=75*DEGREES, theta=-45*DEGREES)
#
#         list_of_charges = [
#             (-1, np.array([-4.5, 0, 0])),
#             (1, np.array([-1, -0.5, 0])),
#         ]
#
#         efield = ElectricField(center = np.array([0, 0, 0]), list_of_charges = list_of_charges)
#         self.add(efield)
#
#
#         point_charges = efield.get_charge()
#         for charge in point_charges:
#             self.add(charge)
#
#         electric_field = efield.get_efield()
#         self.add(electric_field)
# Out:
# Output saved by creating file at animations/potential_gradient_equipot/pge_L.mp4.
