# %%
from manim import *
import matplotlib.pyplot as plt

video_scene = " -v WARNING --disable_caching gauss_beam_Scene"
image_scene = f" -v WARNING --disable_caching -r {2*427},{2*240}  -s gauss_beam_Scene"

# %%
# %%manim -qm --fps 60 $video_scene
#
#
# class gauss_beam_Scene(Scene):
# 	def construct(self):
# 		CVC = Text('CVC', font_size = 12, weight = BOLD, color = WHITE, font = 'Latin Modern Sans').align_on_border(RIGHT + DOWN, buff = 0.2)
# 		self.add(CVC)
#
# 		# headline
# 		headline = Title(r"Gaußstrahl", font_size = 48).align_on_border(UP + LEFT, buff = 0.5).shift(0.5 * RIGHT)
# 		self.add(headline)
# Out:
# Manim Community v0.18.1
