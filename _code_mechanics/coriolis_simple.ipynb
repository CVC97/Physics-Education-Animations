# %%
from manim import *
from numpy import linalg as npl
import jupyter_capture_output

video_scene = " -v WARNING --progress_bar None --disable_caching cs_Scene"
image_scene = f" -v WARNING --progress_bar None --disable_caching -r {2*427},{2*240}  -s cs_Scene"
# Out:
# Manim Community v0.18.0.post0
# Jupyter Capture Output v0.0.11

# %%
# %%capture_video --path "../animations/coriolis_simple/coriolis_simple.mp4"
# %%manim -qm --fps 60 $video_scene
#
#
# class cs_Scene(ThreeDScene):
#     def construct(self):
#         self.camera.background_color = WHITE
# Out:
# Note: The animations/coriolis_simple directory was successfully created.
# Output saved by creating file at animations/coriolis_simple/coriolis_simple.mp4.
