# %%
from manim import *
from numpy import linalg as npl
import math
import matplotlib.pyplot as plt
import jupyter_capture_output

video_scene = " -v WARNING --disable_caching Example"
image_scene = f" -v WARNING --progress_bar None --disable_caching -r {2*427},{2*240}  -s Example"

# %%
class Moon(Mobject):
    def __init__(self, color = RED, **kwargs):
        super().__init__(**kwargs)
        d = Dot(radius = 0.2, color = color, **kwar)
        self.add(d)
    
    def set_color(self, new_color):
        self[0].color = new_color


m1 = Moon(fill_opacity = 0.25)
m1.set_color(GREY)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/carlo/Documents/Studium/Physik_B.Sc/physics-education-animations/animations_code/spring_class.ipynb Cell 2 in 1
#       <a href='vscode-notebook-cell:/home/carlo/Documents/Studium/Physik_B.Sc/physics-education-animations/animations_code/spring_class.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>     def set_color(self, new_color):
#       <a href='vscode-notebook-cell:/home/carlo/Documents/Studium/Physik_B.Sc/physics-education-animations/animations_code/spring_class.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a>         self[0].color = new_color
# ---> <a href='vscode-notebook-cell:/home/carlo/Documents/Studium/Physik_B.Sc/physics-education-animations/animations_code/spring_class.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> m1 = Moon(fill_opacity = 0.25)
#      <a href='vscode-notebook-cell:/home/carlo/Documents/Studium/Physik_B.Sc/physics-education-animations/animations_code/spring_class.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> m1.set_color(GREY)
#
# /home/carlo/Documents/Studium/Physik_B.Sc/physics-education-animations/animations_code/spring_class.ipynb Cell 2 in 3
#       <a href='vscode-notebook-cell:/home/carlo/Documents/Studium/Physik_B.Sc/physics-education-animations/animations_code/spring_class.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> def __init__(self, color = RED, **kwargs):
# ----> <a href='vscode-notebook-cell:/home/carlo/Documents/Studium/Physik_B.Sc/physics-education-animations/animations_code/spring_class.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>     super().__init__(**kwargs)
#       <a href='vscode-notebook-cell:/home/carlo/Documents/Studium/Physik_B.Sc/physics-education-animations/animations_code/spring_class.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a>     d = Dot(radius = 0.2, color = color)
#       <a href='vscode-notebook-cell:/home/carlo/Documents/Studium/Physik_B.Sc/physics-education-animations/animations_code/spring_class.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>     self.add(d)
#
# TypeError: Mobject.__init__() got an unexpected keyword argument 'fill_opacity'

# %%
# %%manim -qm --fps 60 $video_scene
#
#
#
# class Example(Scene):
#     def construct(self):
#
#         d1 = Dot(point= [0,0,0], radius=2)
#         d2 = Dot(point= [1,0,0], radius=2)
#         diff = Difference(d1,d2,fill_opacity=1,stroke_width=0)
#         self.add(m1)
#         self.add(diff)
#         print(m1.color)
# Out:
# white

# %%
s1 = Square()

# %%
circ = Circle()

# %%
s1.add(circ)
# Out:
# Square

# %%
s1.submobjects[0]
# Out:
# Circle
